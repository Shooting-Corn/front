# %% [markdown]
# <a href="https://colab.research.google.com/github/Shooting-Corn/ShootingCorn/blob/front/clown_130.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !unzip "/content/drive/MyDrive/darknet.zip"
# Out:
# Archive:  /content/drive/MyDrive/darknet.zip
#    creating: darknet/
#   inflating: darknet/LICENSE.mit
#   inflating: darknet/.DS_Store
#   inflating: __MACOSX/darknet/._.DS_Store
#   inflating: darknet/LICENSE
#   inflating: darknet/darknet53.conv.74
#   inflating: __MACOSX/darknet/._darknet53.conv.74
#    creating: darknet/python/
#   inflating: darknet/Makefile
#   inflating: __MACOSX/darknet/._Makefile
#   inflating: darknet/LICENSE.meta
#    creating: darknet/include/
#   inflating: darknet/LICENSE.gpl
#    creating: darknet/cfg/
#   inflating: darknet/README.md
#   inflating: darknet/LICENSE.gen
#   inflating: darknet/.gitignore
#   inflating: darknet/LICENSE.v1
#    creating: darknet/examples/
#   inflating: darknet/LICENSE.fuck
#    creating: darknet/scripts/
#    creating: darknet/.git/
#    creating: darknet/data/
#    creating: darknet/src/
#   inflating: darknet/python/proverbot.py
#   inflating: darknet/python/darknet.py
#   inflating: darknet/include/darknet.h
# ...

# %%
# %cd /content/darknet
# !make
# !chmod +x ./darknet
# Out:
# /content/darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:957:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# !rm /content/darknet/backup -r 
# !ln -s /content/drive/'MyDrive'/backup /content/darknet

# %%
# !python2 python/darknet.py
# Out:
# Traceback (most recent call last):
#   File "python/darknet.py", line 48, in <module>
#     lib = CDLL("libdarknet.so", RTLD_GLOBAL)
#   File "/usr/lib/python2.7/ctypes/__init__.py", line 366, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: libdarknet.so: cannot open shared object file: No such file or directory

# %%
# !./darknet detector test data/yolo.data cfg/yolov3_custom_train.cfg yolov3_custom_train_700.weights data/img_504.jpg
# Out:
# Cannot load image "data/labels/32_0.png"
# Cannot load image "data/labels/33_0.png"
# Cannot load image "data/labels/34_0.png"
# Cannot load image "data/labels/35_0.png"
# Cannot load image "data/labels/36_0.png"
# Cannot load image "data/labels/37_0.png"
# Cannot load image "data/labels/38_0.png"
# Cannot load image "data/labels/39_0.png"
# Cannot load image "data/labels/40_0.png"
# Cannot load image "data/labels/41_0.png"
# Cannot load image "data/labels/42_0.png"
# Cannot load image "data/labels/43_0.png"
# Cannot load image "data/labels/44_0.png"
# Cannot load image "data/labels/45_0.png"
# Cannot load image "data/labels/46_0.png"
# Cannot load image "data/labels/47_0.png"
# Cannot load image "data/labels/48_0.png"
# Cannot load image "data/labels/49_0.png"
# Cannot load image "data/labels/50_0.png"
# Cannot load image "data/labels/51_0.png"
# Cannot load image "data/labels/52_0.png"
# Cannot load image "data/labels/53_0.png"
# Cannot load image "data/labels/54_0.png"
# ...
